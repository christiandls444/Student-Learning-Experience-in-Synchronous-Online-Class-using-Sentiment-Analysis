# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 400px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:80px;
#             font-weight: bold;">
#             Grupo De Katsu
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:80px;
#             padding-top:70px;
#             font-size:40px;">
#             Patrick Aristorenas<br><br>
#             Jun Rey Cumpa<br><br>
#             Gabriel Sarmiento<br><br>
#             Christian De Los Santos<br><br>
# </div>
# </div>
# </div>

# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 200px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:30px;
#             font-weight: bold;">
#             Student Learning Experience in Synchronous <br><br>Online Class using Sentiment Analysis
# </div>
# </div>

# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 160px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:30px;
#             font-weight: bold;">
#             Application
# </div>
# </div>

# %%
from PIL import Image, ImageTk
from tkinter import ttk


# Sentiment Detector GUI using Tkinter – Python
# import SentimentIntensityAnalyzer class
# from vaderSentiment.vaderSentiment module.
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# import all methods and classes from the tkinter
from tkinter import *

#===========================================================================

from openpyxl import *

# globally declare wb and sheet variable  
# opening the existing excel file
wb = load_workbook('dss.xlsx')
  
# create the sheet object
sheet = wb.active

def excel():
      
    # resize the width of columns in
    # excel spreadsheet
    sheet.column_dimensions['A'].width = 30
    sheet.column_dimensions['B'].width = 15
    sheet.column_dimensions['C'].width = 15
    sheet.column_dimensions['D'].width = 15
    sheet.column_dimensions['E'].width = 15
    sheet.column_dimensions['F'].width = 30
    sheet.column_dimensions['G'].width = 50
    sheet.column_dimensions['H'].width = 20
  
    # write given data to an excel spreadsheet
    # at particular location
    sheet.cell(row=1, column=1).value = "FULLNAME"
    sheet.cell(row=1, column=2).value = "STUDENT NO"
    sheet.cell(row=1, column=3).value = "COURSE"
    sheet.cell(row=1, column=4).value = "GENDER"
    sheet.cell(row=1, column=5).value = "SECTION"
    sheet.cell(row=1, column=6).value = "EMAIL"
    sheet.cell(row=1, column=7).value = "COMMENT"
    sheet.cell(row=1, column=8).value = "SENTIMENT"


# Function to set focus (cursor)
def focus1(event):
    # set focus on the course_field box
    course_field.focus_set()
  
  
# Function to set focus
def focus2(event):
    # set focus on the sem_field box
    sem_field.focus_set()
  
  
# Function to set focus
def focus3(event):
    # set focus on the form_no_field box
    form_no_field.focus_set()
  
  
# Function to set focus
def focus4(event):
    # set focus on the contact_no_field box
    contact_no_field.focus_set()
  
  
# Function to set focus
def focus5(event):
    # set focus on the email_id_field box
    email_id_field.focus_set()
  
  
# Function to set focus
def focus6(event):
    # set focus on the address_field box
    textArea.focus_set()

    
def focus7(event):
    # set focus on the address_field box
    overallField.focus_set()

    

#============================================================================



# Function for clearing the
# contents of all entry boxes
# And text area.


def clearAll():

    # deleting the content from the entry box
    negativeField.delete(0, END)
    neutralField.delete(0, END)
    positiveField.delete(0, END)
    overallField.delete(0, END)

    # whole content of text area is deleted
    textArea.delete(0, END)
    
    #==========================================================================
    
    name_field.delete(0, END)
    course_field.delete(0, END)
    sem_field.delete(0, END)
    form_no_field.delete(0, END)
    contact_no_field.delete(0, END)
    email_id_field.delete(0, END)

    
    #=============================================================================

# function to print sentiments
# of the sentence.



#========================================================================================

def insert():
      
    # if user not fill any entry
    # then print "empty input"
    if (name_field.get() == "" and
        course_field.get() == "" and
        sem_field.get() == "" and
        form_no_field.get() == "" and
        contact_no_field.get() == "" and
        email_id_field.get() == "" and
        textArea.get() == ""):
              
        print("empty input")
  
    else:
  
        # assigning the max row and max column
        # value upto which data is written
        # in an excel sheet to the variable
        current_row = sheet.max_row
        current_column = sheet.max_column
  
        # get method returns current text
        # as string which we write into
        # excel spreadsheet at particular location
        sheet.cell(row=current_row + 1, column=1).value = name_field.get()
        sheet.cell(row=current_row + 1, column=2).value = course_field.get()
        sheet.cell(row=current_row + 1, column=3).value = sem_field.get()
        sheet.cell(row=current_row + 1, column=4).value = form_no_field.get()
        sheet.cell(row=current_row + 1, column=5).value = contact_no_field.get()
        sheet.cell(row=current_row + 1, column=6).value = email_id_field.get()
        sheet.cell(row=current_row + 1, column=7).value = textArea.get()
        sheet.cell(row=current_row + 1, column=8).value = overallField.get()
  
        # save the file
        wb.save('dss.xlsx')
  
        # set focus on the name_field box
        name_field.focus_set()
  
        clearAll()
#==========================================================================================









def detect_sentiment():

    # get a whole input content from text box
    sentence = textArea.get()

    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()

    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)

    string = str(sentiment_dict['neg']*100) 
    negativeField.insert(10, string)

    string = str(sentiment_dict['neu']*100)
    neutralField.insert(10, string)

    string = str(sentiment_dict['pos']*100) 
    positiveField.insert(10, string)

    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05:
        string = "1"

    elif sentiment_dict['compound'] <= - 0.05:
        string = "0"

    else:
        string = "2"

    overallField.insert(10, string)


# Driver Code
if __name__ == "__main__":

    # Create a GUI window
    gui = Tk()

    # Set the background colour of GUI window
   
    #Define the PhotoImage Constructor by passing the image file
    img= PhotoImage(file='star.png', master= gui)
    img_label= Label(gui,image=img)

#define the position of the image
    img_label.place(x=-10, y=-350)

    # set the name of tkinter GUI window
    gui.title("SLESOC using Sentiment Analysis")

    # Set the configuration of GUI window
    w = 485
    h = 820

    ws = gui.winfo_screenwidth()
    hs = gui.winfo_screenheight()
    x = (ws/2) - (w/2)
    y = (hs/2) - (h/2)

    gui.geometry('%dx%d+%d+%d' % (w, h, x, y))
    

    
    excel()
    #========================================================================
    
    name = Label(gui, text="FULLNAME",bg="#000002" , fg="white",font=('Century', 12, 'bold'))
    
    course = Label(gui, text="STUDENT NO",bg="#000002" , fg="white",font=('Century', 12, 'bold'))
    
    sem = Label(gui, text="COURSE",bg="#000002" , fg="white",font=('Century', 12, 'bold'))
    
    form_no = Label(gui, text="GENDER",bg="#000002" , fg="white",font=('Century', 12, 'bold'))
    
    contact_no = Label(gui, text="SECTION",bg="#000002" , fg="white",font=('Century', 12, 'bold'))
    
    email_id = Label(gui, text="EMAIL",bg="#000002" , fg="white",font=('Century', 12, 'bold'))
    
    
    
    #==========================================================================
    
    # create a label : Enter Your Task
    enterText = Label(gui, text="COMMENT",bg="#000002" , fg="white",font=('Century', 12, 'bold'))

    # create a text area for the root
    # with lunida 13 font
    # text area is for writing the content
    textArea = Text(gui, height=5, width=25, font="lucida 13")

    # create a Submit Button and place into the root window
    # when user press the button, the command or
    # function affiliated to that button is executed
    check = Button(gui, text="CHECK SENTIMENT", fg="white",bg="#ff1414", command=detect_sentiment,font=('Century', 12, 'bold'))

    # Create a negative : label
    negative = Label(gui, text="NEGATIVE RATED AS",bg="#000002" , fg="white",font=('Century', 12, 'bold'))

    # Create a neutral : label
    neutral = Label(gui, text="NEUTRAL RATED AS",bg="#000002" , fg="white",font=('Century', 12, 'bold'))

    # Create a positive : label
    positive = Label(gui, text="POSITIVE RATED AS",bg="#000002" , fg="white",font=('Century', 12, 'bold'))

    # Create a overall : label
    overall = Label(gui, text="OVERALL RATED AS",bg="#000002", fg="white",font=('Century', 12, 'bold'))

    #=====================================================================================
    
    name_field = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    course_field = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    sem_field = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    form_no_field = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    contact_no_field = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    email_id_field = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    textArea = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))
    
    #===================================================================================
    
    # create a text entry box
    negativeField = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))

    # create a text entry box
    neutralField = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))

    # create a text entry box
    positiveField = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12))

    # create a text entry box
    overallField = Entry(gui, justify=CENTER, fg="#262D35",font=("Century", 12,'bold'))

    clear = Button(gui, text="CLEAR ALL", fg="white",bg="#ff1414", command=clearAll,font=('Century', 12, 'bold'))

    Exit = Button(gui, text="SUBMIT", fg="white",bg="#ff1414", command=insert,font=('Century', 12, 'bold'))

    # grid method is used for placing
    # the widgets at respective positions
    # in table like structure.
    #=======================================================================
    
    name_field.bind("<Return>", focus1)
  
    # whenever the enter key is pressed
    # then call the focus2 function
    course_field.bind("<Return>", focus2)
  
    # whenever the enter key is pressed
    # then call the focus3 function
    sem_field.bind("<Return>", focus3)
  
    # whenever the enter key is pressed
    # then call the focus4 function
    form_no_field.bind("<Return>", focus4)
  
    # whenever the enter key is pressed
    # then call the focus5 function
    contact_no_field.bind("<Return>", focus5)
  
    # whenever the enter key is pressed
    # then call the focus6 function
    email_id_field.bind("<Return>", focus6)
    
    
    
    
    
    
    
    
    name.grid(row=0, column=2, ipadx="78", ipady="2")
    
    name_field.grid(row=1, column=2,ipadx="150", ipady="2")
    
    course.grid(row=2, column=2,ipadx="70", ipady="2")
    
    course_field.grid(row=3, column=2,ipadx="150", ipady="2")
    
    sem.grid(row=4, column=2,ipadx="91", ipady="2")
    
    sem_field.grid(row=5, column=2,ipadx="150", ipady="2")
    
    form_no.grid(row=6, column=2,ipadx="103", ipady="2")
    
    form_no_field.grid(row=7, column=2,ipadx="150", ipady="2")
    
    contact_no.grid(row=8, column=2,ipadx="86", ipady="2")
    
    contact_no_field.grid(row=9, column=2,ipadx="150", ipady="2")
    
    email_id.grid(row=10, column=2,ipadx="97", ipady="2")
    
    email_id_field.grid(row=11, column=2,ipadx="150", ipady="2")
    
    #===================================================================
    enterText.grid(row=12, column=2,ipadx="79", ipady="2")

    textArea.grid(row=13, column=2,ipadx="150", ipady="2")

    check.grid(row=14, column=2,ipadx="31", ipady="2")

    negative.grid(row=15, column=2,ipadx="29", ipady="2")
    
    negativeField.grid(row=16, column=2,ipadx="150", ipady="2")

    neutral.grid(row=17, column=2,ipadx="29", ipady="2")
    
    neutralField.grid(row=18, column=2,ipadx="150", ipady="2")

    positive.grid(row=19, column=2,ipadx="29", ipady="2")
    
    positiveField.grid(row=20, column=2,ipadx="150", ipady="2")

    overall.grid(row=21, column=2,ipadx="29", ipady="2")

    overallField.grid(row=22, column=2,ipadx="140", ipady="2")

    clear.grid(row=23, column=2,ipadx="64", ipady="2")

    Exit.grid(row=24, column=2,ipadx="80", ipady="2")

    # start the GUI
    gui.mainloop()

# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 160px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:30px;
#             font-weight: bold;">
#             Dataset
# </div>
# </div>

# %%
import pandas as pd
dataset = pd.read_excel('dss.xlsx')
dataset
# Out:
#                     FULLNAME STUDENT NO            COURSE  GENDER SECTION  \
# 0                       anna    1841234  Computer Science  Female       C
# 1              Jun Rey Cumpa    1840438  Computer Science    Male       C
# 2             Carolyn Angcay    1840425  Computer Science  Female       B
# 3         Myrluna P. Bagacay   184 0579  Computer Science  Female       C
# 4      Jhon Christoper Tupas    1840077  Computer Science    Male       B
# ..                       ...        ...               ...     ...     ...
# 106        Gabriel Sarmiento    1840010  Computer Science    Male       C
# 107        Gabriel Sarmiento    1840010  Computer Science    Male       C
# 108  Christian De Los Santos    1840078  Computer Science    Male       C
# 109  Christian De Los Santos    1840078  Computer Science    Male       C
# 110        Gabriel Sarmiento    1840081  Computer Science    Male       C
#
#                           EMAIL  \
# 0             anna123@gmail.com
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FULLNAME    111 non-null    object
#  1   STUDENT NO  111 non-null    object
#  2   COURSE      111 non-null    object
#  3   GENDER      111 non-null    object
#  4   SECTION     111 non-null    object
#  5   EMAIL       111 non-null    object
#  6   COMMENT     111 non-null    object
#  7   SENTIMENT   111 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 7.1+ KB

# %%
dataset[['GENDER','SECTION', 'SENTIMENT']]
# Out:
#      GENDER SECTION  SENTIMENT
# 0    Female       C          2
# 1      Male       C          1
# 2    Female       B          1
# 3    Female       C          1
# 4      Male       B          0
# ..      ...     ...        ...
# 106    Male       C          0
# 107    Male       C          0
# 108    Male       C          1
# 109    Male       C          1
# 110    Male       C          0
#
# [111 rows x 3 columns]

# %%
dataset.GENDER.value_counts()
# Out:
# Male      78
# Female    33
# Name: GENDER, dtype: int64

# %%
import matplotlib.pyplot as plt

Sentiment_count = dataset.groupby('GENDER').count()
plt.subplot()

plt.bar(Sentiment_count.index.values,Sentiment_count['COMMENT'])
plt.xlabel('GENDER')
plt.ylabel('ALL')
plt.savefig("Gender.png",dpi=200)
plt.show()

# %%
dataset.SECTION.value_counts()
# Out:
# C    40
# A    40
# B    31
# Name: SECTION, dtype: int64

# %%
import matplotlib.pyplot as plt

Sentiment_count = dataset.groupby('SECTION').count()
plt.subplot()

plt.bar(Sentiment_count.index.values,Sentiment_count['COMMENT'])
plt.xlabel('SECTION')
plt.ylabel('ALL')
plt.savefig("Section.png",dpi=200)
plt.show()

# %%
dataset.SENTIMENT.value_counts()
# Out:
# 0    75
# 1    21
# 2    15
# Name: SENTIMENT, dtype: int64

# %%
import matplotlib.pyplot as plt

Sentiment_count = dataset.groupby('SENTIMENT').count()
plt.subplot()

plt.bar(Sentiment_count.index.values,Sentiment_count['COMMENT'])
plt.xlabel('SENTIMENT')
plt.ylabel('ALL')
plt.savefig("Sentiment.png",dpi=200)
plt.show()

# %%
dataset.pivot_table(values=['SENTIMENT'],
index=['GENDER'],
columns='SECTION', aggfunc=[np.sum], fill_value=0).plot(kind='bar')
plt.savefig("Gender_Section.png",dpi=200)

# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 160px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:30px;
#             font-weight: bold;">
#             Wordcloud Positive
# </div>
# </div>

# %%
from wordcloud import WordCloud 
from matplotlib import colors
from nltk.corpus import stopwords
color_list=['#262D35','#ffcc00','#000002',]
colormap=colors.ListedColormap(color_list)

words = ' '.join([Text for Text in dataset[dataset['SENTIMENT']==1]['COMMENT']])
wordCloud = WordCloud(background_color='white',colormap=colormap, mode="RGB", width=2000 , height=1000).generate(words)
plt.figure(figsize=(20,10))
plt.imshow(wordCloud)
#plt.savefig("Wordcloud_Positive.png",dpi=200)
plt.show()

# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 160px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:30px;
#             font-weight: bold;">
#             Wordcloud Neutral
# </div>
# </div>

# %%
from wordcloud import WordCloud 
from matplotlib import colors
from nltk.corpus import stopwords
color_list=['#262D35','#ffcc00','#000002',]
colormap=colors.ListedColormap(color_list)

words = ' '.join([Text for Text in dataset[dataset['SENTIMENT']==2]['COMMENT']])
wordCloud = WordCloud(background_color='white',colormap=colormap, mode="RGB", width=2000 , height=1000).generate(words)
plt.figure(figsize=(20,10))
plt.imshow(wordCloud)
#plt.savefig("Wordcloud_Neutral.png",dpi=200)
plt.show()

# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-color:#000002;
#             height: 160px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:30px;
#             font-weight: bold;">
#             Wordcloud Negative
# </div>
# </div>

# %%
from wordcloud import WordCloud 
from matplotlib import colors
from nltk.corpus import stopwords
color_list=['#262D35','#ffcc00','#000002',]
colormap=colors.ListedColormap(color_list)

words = ' '.join([Text for Text in dataset[dataset['SENTIMENT']==0]['COMMENT']])
wordCloud = WordCloud(background_color='white',colormap=colormap, mode="RGB", width=2000 , height=1000).generate(words)
plt.figure(figsize=(20,10))
plt.imshow(wordCloud)
#plt.savefig("Wordcloud_Negative.png",dpi=200)
plt.show()
